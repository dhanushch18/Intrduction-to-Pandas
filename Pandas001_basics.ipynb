# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanushch18/Intrduction-to-Pandas/blob/main/Pandas001_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas basics

# %%
import pandas as pd

# %%
 df= pd.read_csv("/content/nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST']
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df['EST'] [df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
#data wrangling or data munging is process of cleaning messy data or missing data.

# %%
df.fillna(0,inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
#Dataframe
#It is used o represent data with rows and columns.

# %%
import pandas as pd
data={
    'day':['1','2','3','4'],
    'event':['sunny','windy','rainy','cloudy']
}
df=pd.DataFrame(data)
df
# Out:
#   day   event
# 0   1   sunny
# 1   2   windy
# 2   3   rainy
# 3   4  cloudy
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('day').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('event').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
# ...

# %%
data
# Out:
# {'day': ['1', '2', '3', '4'], 'event': ['sunny', 'windy', 'rainy', 'cloudy']}

# %%
rows,column=df.shape
#shape
#In Pandas, the shape attribute of a DataFrame is used to get the dimensions of the DataFrame, representing the number of rows and columns.

# %%
rows
# Out:
# 4

# %%
column
# Out:
# 2

# %%
df.head()
# Out:
#   day   event
# 0   1   sunny
# 1   2   windy
# 2   3   rainy
# 3   4  cloudy

# %%
import numpy as np
df= pd.read_csv("/content/nyc_weather.csv")

# %%
df.head()
#for printing first 5 rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()
#fr printing last 5 rows
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
type(df['Temperature'])
# Out:
# pandas.core.series.Series

# %%
df[['EST','Humidity','DewPoint']]
# Out:
#           EST  Humidity  DewPoint
# 0    1/1/2016        52        23
# 1    1/2/2016        46        18
# 2    1/3/2016        47        21
# 3    1/4/2016        44         9
# 4    1/5/2016        41        -3
# 5    1/6/2016        35         4
# 6    1/7/2016        33        11
# 7    1/8/2016        64        29
# 8    1/9/2016        77        38
# 9   1/10/2016        71        46
# 10  1/11/2016        37         8
# 11  1/12/2016        53        15
# 12  1/13/2016        42         4
# 13  1/14/2016        47        12
# 14  1/15/2016        62        31
# 15  1/16/2016        70        37
# 16  1/17/2016        66        23
# 17  1/18/2016        53         6
# 18  1/19/2016        42         3
# 19  1/20/2016        49        15
# 20  1/21/2016        45        11
# 21  1/22/2016        41         6
# 22  1/23/2016        78        21
# 23  1/24/2016        53        11
# 24  1/25/2016        54        18
# 25  1/26/2016        56        29
# ...

# %%
df.mean()
# Out:
# <ipython-input-50-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Temperature              34.677419
# DewPoint                 17.838710
# Humidity                 51.677419
# Sea Level PressureIn     29.992903
# VisibilityMiles           9.193548
# WindSpeedMPH              6.892857
# CloudCover                3.129032
# WindDirDegrees          247.129032
# dtype: float64

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...
